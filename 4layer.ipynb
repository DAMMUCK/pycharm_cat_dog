# %%
import os
from keras.preprocessing.image import ImageDataGenerator


rootPath = "./datasets/cat-and-dog"

imageGenerator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=[.2, .2],
    horizontal_flip=True,
    validation_split=.1
)

trainGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'training_set'),
    target_size=(64, 64),
    subset='training'
)

validationGen = imageGenerator.flow_from_directory(
    #os.path.join(rootPath, 'test_set'),
    os.path.join(rootPath, 'training_set'),
    target_size=(64, 64),
    subset='validation'
)

#모델생성
from keras.models import Sequential
from keras import layers

model = Sequential()

model.add(layers.InputLayer(input_shape=(64, 64, 3)))   #이미지 크기 64x64 , 색상을 갖고있기때문에 3(red,green blue)

model.add(layers.Conv2D(64, (3, 3),padding='same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3),padding='same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(256, (3, 3),padding='same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(rate=0.3))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(rate=0.3))
model.add(layers.Dense(2, activation='sigmoid'))

model.summary()

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['acc'],
)

#체크포인트 콜백 사용
import tensorflow as tf
from keras.callbacks import  EarlyStopping

model_dir = './log'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
model_path = model_dir + "/dog_cat.model"

checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=20)


history=model.fit_generator(
    trainGen,
    epochs=50,
    steps_per_epoch=trainGen.samples/40,
    validation_data=validationGen,
    validation_steps=trainGen.samples/40,
    callbacks=[checkpoint,early_stopping]
)


model.save_weights('dog_cat_4layer.h5')
# Out:
# Found 7205 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_186 (Conv2D)          (None, 64, 64, 64)        1792
# _________________________________________________________________
# max_pooling2d_138 (MaxPoolin (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_187 (Conv2D)          (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_139 (MaxPoolin (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_188 (Conv2D)          (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_140 (MaxPoolin (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 16384)             0
# _________________________________________________________________
# dense_81 (Dense)             (None, 128)               2097280
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_82 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_83 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 2,476,482
# Trainable params: 2,476,482
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 181/180 [==============================] - 41s 226ms/step - loss: 0.6906 - acc: 0.5161 - val_loss: 0.6888 - val_acc: 0.5599
# Epoch 00001: val_loss improved from inf to 0.68876, saving model to ./log/dog_cat.model
# Epoch 2/50
# 181/180 [==============================] - 41s 227ms/step - loss: 0.6877 - acc: 0.5546 - val_loss: 0.6726 - val_acc: 0.5887
# Epoch 00002: val_loss improved from 0.68876 to 0.67257, saving model to ./log/dog_cat.model
# Epoch 3/50
# 181/180 [==============================] - 45s 248ms/step - loss: 0.6768 - acc: 0.5817 - val_loss: 0.6764 - val_acc: 0.5546
# Epoch 00003: val_loss did not improve
# Epoch 4/50
# 181/180 [==============================] - 41s 228ms/step - loss: 0.6607 - acc: 0.6010 - val_loss: 0.6530 - val_acc: 0.6157
# Epoch 00004: val_loss improved from 0.67257 to 0.65300, saving model to ./log/dog_cat.model
# Epoch 5/50
# 181/180 [==============================] - 39s 216ms/step - loss: 0.6543 - acc: 0.6114 - val_loss: 0.6347 - val_acc: 0.6426
# Epoch 00005: val_loss improved from 0.65300 to 0.63470, saving model to ./log/dog_cat.model
# Epoch 6/50
# 181/180 [==============================] - 37s 206ms/step - loss: 0.6215 - acc: 0.6576 - val_loss: 0.6257 - val_acc: 0.6480
# Epoch 00006: val_loss improved from 0.63470 to 0.62569, saving model to ./log/dog_cat.model
# Epoch 7/50
# 181/180 [==============================] - 38s 208ms/step - loss: 0.6142 - acc: 0.6616 - val_loss: 0.5709 - val_acc: 0.6953
# Epoch 00007: val_loss improved from 0.62569 to 0.57088, saving model to ./log/dog_cat.model
# Epoch 8/50
# 181/180 [==============================] - 38s 209ms/step - loss: 0.5892 - acc: 0.6840 - val_loss: 0.5662 - val_acc: 0.7147
# Epoch 00008: val_loss improved from 0.57088 to 0.56617, saving model to ./log/dog_cat.model
# Epoch 9/50
# 181/180 [==============================] - 38s 208ms/step - loss: 0.5781 - acc: 0.6966 - val_loss: 0.6284 - val_acc: 0.6413
# Epoch 00009: val_loss did not improve
# Epoch 10/50
# 181/180 [==============================] - 37s 205ms/step - loss: 0.5728 - acc: 0.6994 - val_loss: 0.5819 - val_acc: 0.6877
# Epoch 00010: val_loss did not improve
# Epoch 11/50
# 181/180 [==============================] - 37s 202ms/step - loss: 0.5596 - acc: 0.7144 - val_loss: 0.6151 - val_acc: 0.6367
# Epoch 00011: val_loss did not improve
# Epoch 12/50
# 181/180 [==============================] - 38s 213ms/step - loss: 0.5590 - acc: 0.7146 - val_loss: 0.5073 - val_acc: 0.7470
# Epoch 00012: val_loss improved from 0.56617 to 0.50729, saving model to ./log/dog_cat.model
# Epoch 13/50
# 181/180 [==============================] - 38s 208ms/step - loss: 0.5390 - acc: 0.7259 - val_loss: 0.5221 - val_acc: 0.7371
# Epoch 00013: val_loss did not improve
# Epoch 14/50
# 181/180 [==============================] - 39s 214ms/step - loss: 0.5261 - acc: 0.7425 - val_loss: 0.5095 - val_acc: 0.7413
# Epoch 00014: val_loss did not improve
# Epoch 15/50
# 181/180 [==============================] - 39s 216ms/step - loss: 0.5331 - acc: 0.7368 - val_loss: 0.5249 - val_acc: 0.7541
# Epoch 00015: val_loss did not improve
# Epoch 16/50
# 181/180 [==============================] - 36s 198ms/step - loss: 0.5170 - acc: 0.7489 - val_loss: 0.4965 - val_acc: 0.7481
# Epoch 00016: val_loss improved from 0.50729 to 0.49646, saving model to ./log/dog_cat.model
# Epoch 17/50
# 181/180 [==============================] - 41s 226ms/step - loss: 0.5126 - acc: 0.7484 - val_loss: 0.4940 - val_acc: 0.7598
# Epoch 00017: val_loss improved from 0.49646 to 0.49400, saving model to ./log/dog_cat.model
# Epoch 18/50
# 181/180 [==============================] - 42s 230ms/step - loss: 0.4935 - acc: 0.7572 - val_loss: 0.4829 - val_acc: 0.7645
# Epoch 00018: val_loss improved from 0.49400 to 0.48292, saving model to ./log/dog_cat.model
# Epoch 19/50
# 181/180 [==============================] - 44s 244ms/step - loss: 0.5004 - acc: 0.7523 - val_loss: 0.4918 - val_acc: 0.7534
# Epoch 00019: val_loss did not improve
# Epoch 20/50
# 181/180 [==============================] - 40s 220ms/step - loss: 0.4950 - acc: 0.7620 - val_loss: 0.4775 - val_acc: 0.7706
# Epoch 00020: val_loss improved from 0.48292 to 0.47749, saving model to ./log/dog_cat.model
# Epoch 21/50
# 181/180 [==============================] - 43s 240ms/step - loss: 0.4864 - acc: 0.7642 - val_loss: 0.4897 - val_acc: 0.7554
# Epoch 00021: val_loss did not improve
# Epoch 22/50
# 181/180 [==============================] - 43s 235ms/step - loss: 0.4738 - acc: 0.7756 - val_loss: 0.4783 - val_acc: 0.7610
# Epoch 00022: val_loss did not improve
# Epoch 23/50
# 181/180 [==============================] - 39s 214ms/step - loss: 0.4777 - acc: 0.7696 - val_loss: 0.4789 - val_acc: 0.7698
# Epoch 00023: val_loss did not improve
# Epoch 24/50
# 181/180 [==============================] - 36s 201ms/step - loss: 0.4684 - acc: 0.7775 - val_loss: 0.4585 - val_acc: 0.7839
# Epoch 00024: val_loss improved from 0.47749 to 0.45847, saving model to ./log/dog_cat.model
# Epoch 25/50
# 181/180 [==============================] - 38s 210ms/step - loss: 0.4574 - acc: 0.7836 - val_loss: 0.4684 - val_acc: 0.7658
# Epoch 00025: val_loss did not improve
# Epoch 26/50
# 181/180 [==============================] - 42s 233ms/step - loss: 0.4659 - acc: 0.7807 - val_loss: 0.4714 - val_acc: 0.7692
# Epoch 00026: val_loss did not improve
# Epoch 27/50
# 181/180 [==============================] - 40s 222ms/step - loss: 0.4578 - acc: 0.7836 - val_loss: 0.4430 - val_acc: 0.7897
# Epoch 00027: val_loss improved from 0.45847 to 0.44305, saving model to ./log/dog_cat.model
# Epoch 28/50
# 181/180 [==============================] - 40s 219ms/step - loss: 0.4524 - acc: 0.7870 - val_loss: 0.5612 - val_acc: 0.7184
# Epoch 00028: val_loss did not improve
# Epoch 29/50
# 181/180 [==============================] - 38s 211ms/step - loss: 0.4423 - acc: 0.7989 - val_loss: 0.4361 - val_acc: 0.7976
# Epoch 00029: val_loss improved from 0.44305 to 0.43605, saving model to ./log/dog_cat.model
# Epoch 30/50
# 181/180 [==============================] - 38s 209ms/step - loss: 0.4372 - acc: 0.7976 - val_loss: 0.4506 - val_acc: 0.7929
# Epoch 00030: val_loss did not improve
# Epoch 31/50
# 181/180 [==============================] - 36s 197ms/step - loss: 0.4319 - acc: 0.7980 - val_loss: 0.4305 - val_acc: 0.8007
# Epoch 00031: val_loss improved from 0.43605 to 0.43052, saving model to ./log/dog_cat.model
# Epoch 32/50
# 181/180 [==============================] - 36s 199ms/step - loss: 0.4268 - acc: 0.7978 - val_loss: 0.4365 - val_acc: 0.7976
# Epoch 00032: val_loss did not improve
# Epoch 33/50
# 181/180 [==============================] - 36s 198ms/step - loss: 0.4302 - acc: 0.8010 - val_loss: 0.4340 - val_acc: 0.7970
# Epoch 00033: val_loss did not improve
# Epoch 34/50
# 181/180 [==============================] - 36s 200ms/step - loss: 0.4258 - acc: 0.8113 - val_loss: 0.4254 - val_acc: 0.7997
# Epoch 00034: val_loss improved from 0.43052 to 0.42543, saving model to ./log/dog_cat.model
# Epoch 35/50
# 181/180 [==============================] - 36s 198ms/step - loss: 0.4125 - acc: 0.8053 - val_loss: 0.4296 - val_acc: 0.8070
# Epoch 00035: val_loss did not improve
# Epoch 36/50
# 181/180 [==============================] - 38s 213ms/step - loss: 0.4020 - acc: 0.8239 - val_loss: 0.4475 - val_acc: 0.7946
# Epoch 00036: val_loss did not improve
# Epoch 37/50
# 181/180 [==============================] - 36s 197ms/step - loss: 0.4097 - acc: 0.8131 - val_loss: 0.4428 - val_acc: 0.8013
# Epoch 00037: val_loss did not improve
# Epoch 38/50
# 181/180 [==============================] - 47s 258ms/step - loss: 0.3964 - acc: 0.8234 - val_loss: 0.4161 - val_acc: 0.8084
# Epoch 00038: val_loss improved from 0.42543 to 0.41609, saving model to ./log/dog_cat.model
# Epoch 39/50
# 181/180 [==============================] - 38s 212ms/step - loss: 0.3980 - acc: 0.8213 - val_loss: 0.4249 - val_acc: 0.7934
# Epoch 00039: val_loss did not improve
# Epoch 40/50
# 181/180 [==============================] - 36s 199ms/step - loss: 0.3990 - acc: 0.8121 - val_loss: 0.4147 - val_acc: 0.8064
# Epoch 00040: val_loss improved from 0.41609 to 0.41469, saving model to ./log/dog_cat.model
# Epoch 41/50
# 181/180 [==============================] - 36s 197ms/step - loss: 0.3876 - acc: 0.8300 - val_loss: 0.4300 - val_acc: 0.7973
# Epoch 00041: val_loss did not improve
# Epoch 42/50
# 181/180 [==============================] - 36s 200ms/step - loss: 0.3893 - acc: 0.8184 - val_loss: 0.4554 - val_acc: 0.7819
# Epoch 00042: val_loss did not improve
# Epoch 43/50
# 181/180 [==============================] - 36s 197ms/step - loss: 0.3830 - acc: 0.8272 - val_loss: 0.4034 - val_acc: 0.8132
# Epoch 00043: val_loss improved from 0.41469 to 0.40341, saving model to ./log/dog_cat.model
# Epoch 44/50
# 181/180 [==============================] - 36s 196ms/step - loss: 0.3756 - acc: 0.8321 - val_loss: 0.4040 - val_acc: 0.8161
# Epoch 00044: val_loss did not improve
# Epoch 45/50
# 181/180 [==============================] - 36s 198ms/step - loss: 0.3725 - acc: 0.8327 - val_loss: 0.3966 - val_acc: 0.8153
# Epoch 00045: val_loss improved from 0.40341 to 0.39661, saving model to ./log/dog_cat.model
# Epoch 46/50
# 181/180 [==============================] - 36s 200ms/step - loss: 0.3761 - acc: 0.8239 - val_loss: 0.3810 - val_acc: 0.8235
# Epoch 00046: val_loss improved from 0.39661 to 0.38096, saving model to ./log/dog_cat.model
# Epoch 47/50
# 181/180 [==============================] - 36s 196ms/step - loss: 0.3654 - acc: 0.8367 - val_loss: 0.4201 - val_acc: 0.8231
# Epoch 00047: val_loss did not improve
# Epoch 48/50
# 181/180 [==============================] - 36s 197ms/step - loss: 0.3687 - acc: 0.8343 - val_loss: 0.3811 - val_acc: 0.8269
# Epoch 00048: val_loss did not improve
# Epoch 49/50
# 181/180 [==============================] - 36s 199ms/step - loss: 0.3692 - acc: 0.8308 - val_loss: 0.3985 - val_acc: 0.8089
# Epoch 00049: val_loss did not improve
# Epoch 50/50
# 181/180 [==============================] - 36s 198ms/step - loss: 0.3628 - acc: 0.8392 - val_loss: 0.3962 - val_acc: 0.8220
# Epoch 00050: val_loss did not improve

# %%
import matplotlib.pyplot as plt

def show_graph(history_dict):
    accuracy = history_dict['acc']
    val_accuracy = history_dict['val_acc']
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']

    epochs = range(1, len(loss) + 1)
    
    plt.figure(figsize=(16, 1))
    
    plt.subplot(121)
    plt.subplots_adjust(top=2)
    plt.plot(epochs, accuracy, 'yo', label='Training accuracy')
    plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
    plt.title('Trainging and validation accuracy and loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy and Loss')

    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
              fancybox=True, shadow=True, ncol=5)
#     plt.legend(bbox_to_anchor=(1, -0.1))

    plt.subplot(122)
    plt.plot(epochs, loss, 'yo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=True, shadow=True, ncol=5)
#     plt.legend(bbox_to_anchor=(1, 0))

    plt.show()

# %%
model.save_weights('dog_cat_4layer.h5')

show_graph(history.history)


testGenerator = ImageDataGenerator(
    rescale=1./255
)

testGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'test_set'),
    target_size=(64, 64),
)

model.evaluate_generator(testGen)
# Out:
# Found 2023 images belonging to 2 classes.
# [0.4859715262322042, 0.7750865052787019]

# %%
from keras.preprocessing.image import array_to_img
import numpy as np

cls_index = ['고양이', '개']

imgs = testGen.next()
arr = imgs[0][0]
img = array_to_img(arr).resize((128, 128))
plt.imshow(img)
result = model.predict_classes(arr.reshape(1, 64, 64, 3))
print('예측: {}'.format(cls_index[result[0]]))
print('정답: {}'.format(cls_index[np.argmax(imgs[1][0])]))
# Out:
# 예측: 개
# 정답: 개
